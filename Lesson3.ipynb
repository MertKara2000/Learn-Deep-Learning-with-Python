# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.333)
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_options))

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [0, 1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1,2,3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))
            
            for l in range(conv_layer-1):
            
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))
            
            model.add(Flatten()) 
            
            for l in range (dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))
                
            model.add(Dense(1))
            model.add(Activation('sigmoid'))



            model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

            model.fit(X, y,
                      batch_size=32,
                      epochs=20,
                      validation_split=0.3,
                      callbacks=[tensorboard])
# Out:
# Epoch 1/20
# 546/546 [==============================] - 7s 13ms/step - loss: 0.6218 - accuracy: 0.6544 - val_loss: 0.5753 - val_accuracy: 0.7165
# Epoch 2/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5412 - accuracy: 0.7323 - val_loss: 0.5829 - val_accuracy: 0.6925
# Epoch 3/20
# 546/546 [==============================] - 6s 12ms/step - loss: 0.4980 - accuracy: 0.7619 - val_loss: 0.5278 - val_accuracy: 0.7390
# Epoch 4/20
# 546/546 [==============================] - 6s 12ms/step - loss: 0.4646 - accuracy: 0.7824 - val_loss: 0.5209 - val_accuracy: 0.7477
# Epoch 5/20
# 546/546 [==============================] - 6s 12ms/step - loss: 0.4373 - accuracy: 0.7992 - val_loss: 0.5266 - val_accuracy: 0.7386
# Epoch 6/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.4162 - accuracy: 0.8112 - val_loss: 0.5304 - val_accuracy: 0.7366
# Epoch 7/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3943 - accuracy: 0.8237 - val_loss: 0.5286 - val_accuracy: 0.7448
# Epoch 8/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3781 - accuracy: 0.8343 - val_loss: 0.5801 - val_accuracy: 0.7261
# Epoch 9/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3600 - accuracy: 0.8425 - val_loss: 0.5440 - val_accuracy: 0.7401
# Epoch 10/20
# 546/546 [==============================] - 7s 12ms/step - loss: 0.3423 - accuracy: 0.8540 - val_loss: 0.5809 - val_accuracy: 0.7249
# Epoch 11/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3276 - accuracy: 0.8620 - val_loss: 0.6007 - val_accuracy: 0.7297
# Epoch 12/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.3125 - accuracy: 0.8680 - val_loss: 0.5643 - val_accuracy: 0.7386
# Epoch 13/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2977 - accuracy: 0.8761 - val_loss: 0.5832 - val_accuracy: 0.7346
# Epoch 14/20
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2837 - accuracy: 0.8856 - val_loss: 0.6128 - val_accuracy: 0.7378
# Epoch 15/20
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2660 - accuracy: 0.8947 - val_loss: 0.6013 - val_accuracy: 0.7328
# Epoch 16/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2573 - accuracy: 0.9010 - val_loss: 0.6158 - val_accuracy: 0.7313
# Epoch 17/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2396 - accuracy: 0.9106 - val_loss: 0.6394 - val_accuracy: 0.7310
# Epoch 18/20
# 546/546 [==============================] - 6s 11ms/step - loss: 0.2278 - accuracy: 0.9153 - val_loss: 0.6345 - val_accuracy: 0.7322
# Epoch 19/20
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2175 - accuracy: 0.9219 - val_loss: 0.6650 - val_accuracy: 0.7243
# Epoch 20/20
# 546/546 [==============================] - 6s 12ms/step - loss: 0.2067 - accuracy: 0.9265 - val_loss: 0.6896 - val_accuracy: 0.7251
# Epoch 1/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.6392 - accuracy: 0.6258 - val_loss: 0.5590 - val_accuracy: 0.7278
# Epoch 2/20
# 546/546 [==============================] - 7s 13ms/step - loss: 0.5409 - accuracy: 0.7263 - val_loss: 0.5120 - val_accuracy: 0.7544
# Epoch 3/20
# 546/546 [==============================] - 7s 13ms/step - loss: 0.4917 - accuracy: 0.7650 - val_loss: 0.5037 - val_accuracy: 0.7611
# Epoch 4/20
# 546/546 [==============================] - 7s 13ms/step - loss: 0.4638 - accuracy: 0.7822 - val_loss: 0.4720 - val_accuracy: 0.7785
# Epoch 5/20
# 546/546 [==============================] - 7s 13ms/step - loss: 0.4395 - accuracy: 0.7980 - val_loss: 0.4714 - val_accuracy: 0.7741
# Epoch 6/20
# 546/546 [==============================] - 7s 13ms/step - loss: 0.4153 - accuracy: 0.8096 - val_loss: 0.4639 - val_accuracy: 0.7813
# Epoch 7/20
# 546/546 [==============================] - 7s 13ms/step - loss: 0.3953 - accuracy: 0.8237 - val_loss: 0.4656 - val_accuracy: 0.7819
# Epoch 8/20
# 546/546 [==============================] - 8s 14ms/step - loss: 0.3746 - accuracy: 0.8271 - val_loss: 0.4636 - val_accuracy: 0.7886
# Epoch 9/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.3555 - accuracy: 0.8422 - val_loss: 0.4550 - val_accuracy: 0.7920
# Epoch 10/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.3362 - accuracy: 0.8544 - val_loss: 0.4782 - val_accuracy: 0.7861
# Epoch 11/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.3268 - accuracy: 0.8580 - val_loss: 0.4751 - val_accuracy: 0.7855
# Epoch 12/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.3089 - accuracy: 0.8677 - val_loss: 0.4891 - val_accuracy: 0.7835
# Epoch 13/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.2952 - accuracy: 0.8725 - val_loss: 0.4867 - val_accuracy: 0.7913
# Epoch 14/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.2799 - accuracy: 0.8832 - val_loss: 0.4915 - val_accuracy: 0.7974
# Epoch 15/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.2662 - accuracy: 0.8884 - val_loss: 0.5465 - val_accuracy: 0.7778
# Epoch 16/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.2531 - accuracy: 0.8941 - val_loss: 0.5041 - val_accuracy: 0.7906
# Epoch 17/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.2402 - accuracy: 0.9007 - val_loss: 0.5156 - val_accuracy: 0.7970
# Epoch 18/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.2330 - accuracy: 0.9045 - val_loss: 0.5337 - val_accuracy: 0.7913
# Epoch 19/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.2220 - accuracy: 0.9112 - val_loss: 0.5727 - val_accuracy: 0.7795
# Epoch 20/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.2085 - accuracy: 0.9174 - val_loss: 0.5618 - val_accuracy: 0.7924
# Epoch 1/20
# 546/546 [==============================] - 10s 17ms/step - loss: 0.6496 - accuracy: 0.6128 - val_loss: 0.5859 - val_accuracy: 0.6903
# Epoch 2/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.5363 - accuracy: 0.7311 - val_loss: 0.5482 - val_accuracy: 0.7300
# Epoch 3/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.4821 - accuracy: 0.7701 - val_loss: 0.4712 - val_accuracy: 0.7781
# Epoch 4/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.4452 - accuracy: 0.7932 - val_loss: 0.4756 - val_accuracy: 0.7728
# Epoch 5/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.4251 - accuracy: 0.8045 - val_loss: 0.5197 - val_accuracy: 0.7464
# Epoch 6/20
# 546/546 [==============================] - 8s 16ms/step - loss: 0.4009 - accuracy: 0.8188 - val_loss: 0.4454 - val_accuracy: 0.7910
# Epoch 7/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.3815 - accuracy: 0.8305 - val_loss: 0.4103 - val_accuracy: 0.8109
# Epoch 8/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.3610 - accuracy: 0.8386 - val_loss: 0.3986 - val_accuracy: 0.8206
# Epoch 9/20
# 546/546 [==============================] - 9s 16ms/step - loss: 0.3454 - accuracy: 0.8473 - val_loss: 0.4272 - val_accuracy: 0.8088
# Epoch 10/20
# 546/546 [==============================] - 8s 15ms/step - loss: 0.3289 - accuracy: 0.8566 - val_loss: 0.4255 - val_accuracy: 0.8135
# Epoch 11/20
# 546/546 [==============================] - 8s 14ms/step - loss: 0.3109 - accuracy: 0.8643 - val_loss: 0.4009 - val_accuracy: 0.8247
# Epoch 12/20
# 546/546 [==============================] - 8s 14ms/step - loss: 0.2998 - accuracy: 0.8720 - val_loss: 0.4182 - val_accuracy: 0.8167
# Epoch 13/20
# 546/546 [==============================] - 7s 14ms/step - loss: 0.2868 - accuracy: 0.8777 - val_loss: 0.4140 - val_accuracy: 0.8192
# Epoch 14/20
# 546/546 [==============================] - 8s 14ms/step - loss: 0.2731 - accuracy: 0.8817 - val_loss: 0.4201 - val_accuracy: 0.8248
# Epoch 15/20
# 546/546 [==============================] - 7s 14ms/step - loss: 0.2623 - accuracy: 0.8862 - val_loss: 0.4574 - val_accuracy: 0.8159
# Epoch 16/20
# 546/546 [==============================] - 7s 14ms/step - loss: 0.2531 - accuracy: 0.8907 - val_loss: 0.4105 - val_accuracy: 0.8310
# Epoch 17/20
# 546/546 [==============================] - 8s 14ms/step - loss: 0.2413 - accuracy: 0.8963 - val_loss: 0.4084 - val_accuracy: 0.8295
# Epoch 18/20
# 546/546 [==============================] - 7s 14ms/step - loss: 0.2298 - accuracy: 0.9012 - val_loss: 0.4099 - val_accuracy: 0.8373
# Epoch 19/20
# 546/546 [==============================] - 8s 14ms/step - loss: 0.2138 - accuracy: 0.9094 - val_loss: 0.4222 - val_accuracy: 0.8322
# Epoch 20/20
# 546/546 [==============================] - 8s 14ms/step - loss: 0.2054 - accuracy: 0.9170 - val_loss: 0.4347 - val_accuracy: 0.8320
# Epoch 1/20
# 546/546 [==============================] - 11s 19ms/step - loss: 0.6208 - accuracy: 0.6473 - val_loss: 0.5511 - val_accuracy: 0.7257
# Epoch 2/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.5218 - accuracy: 0.7429 - val_loss: 0.5389 - val_accuracy: 0.7345
# Epoch 3/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.4785 - accuracy: 0.7725 - val_loss: 0.5307 - val_accuracy: 0.7377
# Epoch 4/20
# 546/546 [==============================] - 9s 17ms/step - loss: 0.4426 - accuracy: 0.7967 - val_loss: 0.5255 - val_accuracy: 0.7405
# Epoch 5/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4198 - accuracy: 0.8103 - val_loss: 0.5281 - val_accuracy: 0.7487
# Epoch 6/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.3905 - accuracy: 0.8237 - val_loss: 0.6112 - val_accuracy: 0.7062
# Epoch 7/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.3645 - accuracy: 0.8411 - val_loss: 0.5482 - val_accuracy: 0.7409
# Epoch 8/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.3412 - accuracy: 0.8527 - val_loss: 0.5552 - val_accuracy: 0.7370
# Epoch 9/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.3151 - accuracy: 0.8689 - val_loss: 0.5732 - val_accuracy: 0.7408
# Epoch 10/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.2898 - accuracy: 0.8802 - val_loss: 0.5986 - val_accuracy: 0.7298
# Epoch 11/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.2681 - accuracy: 0.8956 - val_loss: 0.5883 - val_accuracy: 0.7408
# Epoch 12/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.2478 - accuracy: 0.9022 - val_loss: 0.6166 - val_accuracy: 0.7386
# Epoch 13/20
# 546/546 [==============================] - 10s 17ms/step - loss: 0.2282 - accuracy: 0.9174 - val_loss: 0.6506 - val_accuracy: 0.7282
# Epoch 14/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.2103 - accuracy: 0.9236 - val_loss: 0.6579 - val_accuracy: 0.7309
# Epoch 15/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1901 - accuracy: 0.9343 - val_loss: 0.7497 - val_accuracy: 0.7139
# Epoch 16/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1766 - accuracy: 0.9388 - val_loss: 0.6881 - val_accuracy: 0.7338
# Epoch 17/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1597 - accuracy: 0.9495 - val_loss: 0.7289 - val_accuracy: 0.7278
# Epoch 18/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1439 - accuracy: 0.9583 - val_loss: 0.7677 - val_accuracy: 0.7230
# Epoch 19/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1332 - accuracy: 0.9637 - val_loss: 0.7627 - val_accuracy: 0.7269
# Epoch 20/20
# 546/546 [==============================] - 10s 18ms/step - loss: 0.1177 - accuracy: 0.9693 - val_loss: 0.7819 - val_accuracy: 0.7243
# Epoch 1/20
# 546/546 [==============================] - 15s 26ms/step - loss: 0.6338 - accuracy: 0.6325 - val_loss: 0.5788 - val_accuracy: 0.6988
# Epoch 2/20
# 546/546 [==============================] - 13s 24ms/step - loss: 0.5258 - accuracy: 0.7398 - val_loss: 0.5066 - val_accuracy: 0.7564
# Epoch 3/20
# 546/546 [==============================] - 13s 24ms/step - loss: 0.4782 - accuracy: 0.7718 - val_loss: 0.4815 - val_accuracy: 0.7745
# Epoch 4/20
# 546/546 [==============================] - 13s 24ms/step - loss: 0.4424 - accuracy: 0.7988 - val_loss: 0.4642 - val_accuracy: 0.7829
# Epoch 5/20
# 546/546 [==============================] - 13s 24ms/step - loss: 0.4046 - accuracy: 0.8159 - val_loss: 0.4468 - val_accuracy: 0.7988
# Epoch 6/20
# 546/546 [==============================] - 13s 24ms/step - loss: 0.3771 - accuracy: 0.8308 - val_loss: 0.4673 - val_accuracy: 0.7866
# Epoch 7/20
# 546/546 [==============================] - 13s 24ms/step - loss: 0.3531 - accuracy: 0.8447 - val_loss: 0.4558 - val_accuracy: 0.7952
# Epoch 8/20
# 546/546 [==============================] - 13s 24ms/step - loss: 0.3329 - accuracy: 0.8533 - val_loss: 0.4410 - val_accuracy: 0.8060
# Epoch 9/20
# 546/546 [==============================] - 13s 24ms/step - loss: 0.3093 - accuracy: 0.8653 - val_loss: 0.4915 - val_accuracy: 0.7904
# Epoch 10/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.2902 - accuracy: 0.8740 - val_loss: 0.4695 - val_accuracy: 0.8033
# Epoch 11/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.2727 - accuracy: 0.8852 - val_loss: 0.4695 - val_accuracy: 0.7988
# Epoch 12/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.2504 - accuracy: 0.8965 - val_loss: 0.4940 - val_accuracy: 0.7989
# Epoch 13/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.2334 - accuracy: 0.9021 - val_loss: 0.5041 - val_accuracy: 0.8048
# Epoch 14/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.2133 - accuracy: 0.9126 - val_loss: 0.5870 - val_accuracy: 0.7793
# Epoch 15/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.2036 - accuracy: 0.9174 - val_loss: 0.5256 - val_accuracy: 0.8025
# Epoch 16/20
# 546/546 [==============================] - 14s 26ms/step - loss: 0.1844 - accuracy: 0.9245 - val_loss: 0.5579 - val_accuracy: 0.7941
# Epoch 17/20
# 546/546 [==============================] - 14s 26ms/step - loss: 0.1733 - accuracy: 0.9298 - val_loss: 0.5678 - val_accuracy: 0.7968
# Epoch 18/20
# 546/546 [==============================] - 14s 26ms/step - loss: 0.1559 - accuracy: 0.9375 - val_loss: 0.6020 - val_accuracy: 0.7882
# Epoch 19/20
# 546/546 [==============================] - 14s 26ms/step - loss: 0.1413 - accuracy: 0.9474 - val_loss: 0.6392 - val_accuracy: 0.7946
# Epoch 20/20
# 546/546 [==============================] - 13s 25ms/step - loss: 0.1274 - accuracy: 0.9527 - val_loss: 0.7277 - val_accuracy: 0.7765
# Epoch 1/20
# 546/546 [==============================] - 15s 27ms/step - loss: 0.6532 - accuracy: 0.6025 - val_loss: 0.5753 - val_accuracy: 0.7003
# Epoch 2/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.5350 - accuracy: 0.7352 - val_loss: 0.4958 - val_accuracy: 0.7600
# Epoch 3/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.4666 - accuracy: 0.7815 - val_loss: 0.4674 - val_accuracy: 0.7797
# Epoch 4/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.4202 - accuracy: 0.8066 - val_loss: 0.4187 - val_accuracy: 0.8060
# Epoch 5/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.3790 - accuracy: 0.8304 - val_loss: 0.4085 - val_accuracy: 0.8121
# Epoch 6/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.3491 - accuracy: 0.8484 - val_loss: 0.3946 - val_accuracy: 0.8223
# Epoch 7/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.3182 - accuracy: 0.8607 - val_loss: 0.3915 - val_accuracy: 0.8252
# Epoch 8/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.2859 - accuracy: 0.8775 - val_loss: 0.3998 - val_accuracy: 0.8268
# Epoch 9/20
# 546/546 [==============================] - 14s 26ms/step - loss: 0.2612 - accuracy: 0.8880 - val_loss: 0.3760 - val_accuracy: 0.8387
# Epoch 10/20
# 546/546 [==============================] - 14s 26ms/step - loss: 0.2354 - accuracy: 0.9014 - val_loss: 0.4222 - val_accuracy: 0.8262
# Epoch 11/20
# 546/546 [==============================] - 14s 26ms/step - loss: 0.2148 - accuracy: 0.9115 - val_loss: 0.4086 - val_accuracy: 0.8350
# Epoch 12/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.1854 - accuracy: 0.9249 - val_loss: 0.4027 - val_accuracy: 0.8453
# Epoch 13/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.1656 - accuracy: 0.9343 - val_loss: 0.4187 - val_accuracy: 0.8366
# Epoch 14/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.1459 - accuracy: 0.9434 - val_loss: 0.4784 - val_accuracy: 0.8343
# Epoch 15/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.1274 - accuracy: 0.9518 - val_loss: 0.4789 - val_accuracy: 0.8350
# Epoch 16/20
# 546/546 [==============================] - 15s 27ms/step - loss: 0.1057 - accuracy: 0.9605 - val_loss: 0.5190 - val_accuracy: 0.8328
# Epoch 17/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.0997 - accuracy: 0.9621 - val_loss: 0.5425 - val_accuracy: 0.8310
# Epoch 18/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.0870 - accuracy: 0.9666 - val_loss: 0.5669 - val_accuracy: 0.8339
# Epoch 19/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.0653 - accuracy: 0.9786 - val_loss: 0.5942 - val_accuracy: 0.8307
# Epoch 20/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.0622 - accuracy: 0.9782 - val_loss: 0.5985 - val_accuracy: 0.8393
# Epoch 1/20
# 546/546 [==============================] - 17s 31ms/step - loss: 0.6333 - accuracy: 0.6432 - val_loss: 0.5875 - val_accuracy: 0.6887
# Epoch 2/20
# 546/546 [==============================] - 15s 28ms/step - loss: 0.5313 - accuracy: 0.7403 - val_loss: 0.5468 - val_accuracy: 0.7233
# Epoch 3/20
# 546/546 [==============================] - 15s 28ms/step - loss: 0.4751 - accuracy: 0.7736 - val_loss: 0.5457 - val_accuracy: 0.7309
# Epoch 4/20
# 546/546 [==============================] - 15s 28ms/step - loss: 0.4366 - accuracy: 0.7990 - val_loss: 0.5386 - val_accuracy: 0.7305
# Epoch 5/20
# 546/546 [==============================] - 15s 28ms/step - loss: 0.3988 - accuracy: 0.8190 - val_loss: 0.5438 - val_accuracy: 0.7380
# Epoch 6/20
# 546/546 [==============================] - 15s 28ms/step - loss: 0.3602 - accuracy: 0.8409 - val_loss: 0.5550 - val_accuracy: 0.7340
# Epoch 7/20
# 546/546 [==============================] - 16s 29ms/step - loss: 0.3240 - accuracy: 0.8630 - val_loss: 0.5825 - val_accuracy: 0.7344
# Epoch 8/20
# 546/546 [==============================] - 16s 29ms/step - loss: 0.2907 - accuracy: 0.8810 - val_loss: 0.5980 - val_accuracy: 0.7308
# Epoch 9/20
# 546/546 [==============================] - 16s 29ms/step - loss: 0.2552 - accuracy: 0.8985 - val_loss: 0.6166 - val_accuracy: 0.7326
# Epoch 10/20
# 546/546 [==============================] - 15s 28ms/step - loss: 0.2284 - accuracy: 0.9136 - val_loss: 0.6436 - val_accuracy: 0.7261
# Epoch 11/20
# 546/546 [==============================] - 15s 28ms/step - loss: 0.1965 - accuracy: 0.9301 - val_loss: 0.6851 - val_accuracy: 0.7304
# Epoch 12/20
# 379/546 [===================>..........] - ETA: 4s - loss: 0.1660 - accuracy: 0.9474
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-dd8669cb26bd> in <module>
#      57                       epochs=20,
#      58                       validation_split=0.3,
# ---> 59                       callbacks=[tensorboard])
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1186               logs = tmp_logs  # No error, now safe to assign to logs.
#    1187               end_step = step + data_handler.step_increment
# -> 1188               callbacks.on_train_batch_end(end_step, logs)
#    1189               if self.stop_training:
#    1190                 break
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#     455     """
#     456     if self._should_call_train_batch_hooks:
# --> 457       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     458
#     459   def on_test_batch_begin(self, batch, logs=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     315       self._call_batch_begin_hook(mode, batch, logs)
#     316     elif hook == 'end':
# --> 317       self._call_batch_end_hook(mode, batch, logs)
#     318     else:
#     319       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     335       self._batch_times.append(batch_time)
#     336
# --> 337     self._call_batch_hook_helper(hook_name, batch, logs)
#     338
#     339     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     373     for callback in self.callbacks:
#     374       hook = getattr(callback, hook_name)
# --> 375       hook(batch, logs)
#     376
#     377     if self._check_timing:
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\callbacks.py in on_train_batch_end(self, batch, logs)
#    1027
#    1028   def on_train_batch_end(self, batch, logs=None):
# -> 1029     self._batch_update_progbar(batch, logs)
#    1030
#    1031   def on_test_batch_end(self, batch, logs=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\callbacks.py in _batch_update_progbar(self, batch, logs)
#    1099     if self.verbose == 1:
#    1100       # Only block async when verbose = 1.
# -> 1101       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1102       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1103
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     517     return t  # Don't turn ragged or sparse tensors to NumPy.
#     518
# --> 519   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     520
#     521
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     865
#     866   return pack_sequence_as(
# --> 867       structure[0], [func(*x) for x in entries],
#     868       expand_composites=expand_composites)
#     869
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     513   def _to_single_numpy_or_python_type(t):
#     514     if isinstance(t, ops.Tensor):
# --> 515       x = t.numpy()
#     516       return x.item() if np.ndim(x) == 0 else x
#     517     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1092     """
#    1093     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1094     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1095     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1096
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1058   def _numpy(self):
#    1059     try:
# -> 1060       return self._numpy_internal()
#    1061     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1062       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:
